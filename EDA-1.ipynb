# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
review=pd.read_excel("D:\DS-Project3\hotel_reviews (1).xlsx")
review
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...     4.0
# 1      ok nothing special charge diamond member hilto...     2.0
# 2      nice rooms not 4* experience hotel monaco seat...     3.0
# 3      unique, great stay, wonderful time hotel monac...     5.0
# 4      great stay great stay, went seahawk game aweso...     5.0
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0
# 20487  great location price view hotel great quick pl...     4.0
# 20488  ok just looks nice modern outside, desk staff ...     2.0
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0
# 20490  people talking, ca n't believe excellent ratin...     2.0
#
# [20491 rows x 2 columns]

# %%
review.shape
# Out:
# (20491, 2)

# %%
review.describe
# Out:
# <bound method NDFrame.describe of                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...     4.0
# 1      ok nothing special charge diamond member hilto...     2.0
# 2      nice rooms not 4* experience hotel monaco seat...     3.0
# 3      unique, great stay, wonderful time hotel monac...     5.0
# 4      great stay great stay, went seahawk game aweso...     5.0
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0
# 20487  great location price view hotel great quick pl...     4.0
# 20488  ok just looks nice modern outside, desk staff ...     2.0
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0
# 20490  people talking, ca n't believe excellent ratin...     2.0
#
# [20491 rows x 2 columns]>

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 320.3+ KB

# %%
review.isnull().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %%
review.Rating.unique()
# Out:
# array([4., 2., 3., 5., 1.])

# %%
review.Rating.mean()
# Out:
# 3.952222927138744

# %%
review.Rating.value_counts()
# Out:
# 5.0    9054
# 4.0    6039
# 3.0    2184
# 2.0    1793
# 1.0    1421
# Name: Rating, dtype: int64

# %%
review['Rating'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
review['review_len'] = review.Review.apply(len)
review.head()
# Out:
#                                               Review  Rating  review_len
# 0  nice hotel expensive parking got good deal sta...     4.0         593
# 1  ok nothing special charge diamond member hilto...     2.0        1689
# 2  nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3  unique, great stay, wonderful time hotel monac...     5.0         600
# 4  great stay great stay, went seahawk game aweso...     5.0        1281

# %%
review['review_len'] = review.Review.apply(len)
review.tail()
# Out:
#                                                   Review  Rating  review_len
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620

# %%
a=review.iloc[:,0].str.split(" ")
a
# Out:
# 0        [nice, hotel, expensive, parking, got, good, d...
# 1        [ok, nothing, special, charge, diamond, member...
# 2        [nice, rooms, not, 4*, experience, hotel, mona...
# 3        [unique,, great, stay,, wonderful, time, hotel...
# 4        [great, stay, great, stay,, went, seahawk, gam...
#                                ...
# 20486    [best, kept, secret, 3rd, time, staying, charm...
# 20487    [great, location, price, view, hotel, great, q...
# 20488    [ok, just, looks, nice, modern, outside,, desk...
# 20489    [hotel, theft, ruined, vacation, hotel, opened...
# 20490    [people, talking,, ca, n't, believe, excellent...
# Name: Review, Length: 20491, dtype: object

# %%
length=[]
for i in a:
    length.append(len(i))
length
# Out:
# [89,
#  252,
#  219,
#  91,
#  193,
#  136,
#  103,
#  87,
#  61,
#  37,
#  49,
#  54,
#  86,
#  72,
#  29,
#  216,
#  244,
#  146,
#  24,
#  158,
#  173,
#  23,
#  48,
#  131,
#  37,
#  72,
#  44,
#  72,
#  159,
#  36,
#  39,
#  63,
#  88,
#  83,
#  49,
#  85,
#  136,
#  40,
#  64,
#  50,
#  120,
#  62,
#  26,
#  58,
#  39,
#  211,
#  72,
#  73,
#  56,
#  39,
#  47,
#  86,
#  66,
#  30,
#  133,
#  111,
#  63,
#  216,
#  38,
#  126,
#  58,
#  57,
#  58,
#  100,
#  80,
#  18,
#  78,
#  217,
#  28,
#  16,
#  34,
#  236,
#  90,
#  54,
#  38,
#  131,
#  60,
#  38,
#  45,
#  125,
#  108,
#  21,
#  115,
#  103,
#  47,
#  73,
#  56,
#  96,
#  152,
#  225,
#  43,
#  23,
#  228,
#  73,
#  143,
#  29,
#  87,
#  84,
#  131,
#  126,
#  54,
#  92,
#  167,
#  110,
#  64,
#  81,
#  226,
#  49,
#  230,
#  49,
#  209,
#  28,
#  122,
#  130,
#  53,
#  105,
#  73,
#  18,
#  28,
#  56,
#  30,
#  126,
#  65,
#  75,
#  34,
#  70,
#  70,
#  46,
#  114,
#  106,
#  128,
#  79,
#  130,
#  84,
#  116,
#  83,
# ...

# %%
review['word_length']=length
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length
# 0               89
# ...

# %%
rating_length=review.groupby(["Rating"]).mean()
rating_length
# Out:
#         review_len  word_length
# Rating
# 1.0     769.940183   114.365236
# 2.0     867.645287   128.598438
# 3.0     785.000000   116.705586
# 4.0     745.688690   109.771154
# 5.0     661.981445    95.962889

# %%
import matplotlib.pyplot as plt
plt.bar(rating_length.index,rating_length.review_len)
# Out:
# <BarContainer object of 5 artists>

# %%
import seaborn as sns
fig, axes = plt.subplots(1,5)
for i in enumerate(axes):
    df1=pd.DataFrame()
    df1["review_len"]=review["review_len"].where(review["Rating"]==i[0]+1).dropna()
    sns.boxplot(review[review.Rating==i[0]+1].iloc[:,2],ax=i[1])

# %%
plt.figure(figsize=(12,8))
colors=["red","yellow","green","blue","pink"]
for i in range(1,6):
    review[review.Rating==i].review_len.plot(bins=30,kind="hist",color=colors[i-1],label=i,alpha=1.0-i/10)
    #sms[sms.label=='ham'].message_len.plot(bins=35, kind='hist', color='blue', label='Ham message', alpha=0.6)
    #sms[sms.label=='spam'].message_len.plot(kind='hist', color='red', label='spam message', alpha=0.6)
plt.legend()
plt.xlabel("Review Length")
# Out:
# Text(0.5, 0, 'Review Length')

# %%
import seaborn as sns
fig, axes = plt.subplots(5,1,sharex='col', sharey='col')
fig.set_figheight(15)
fig.set_figwidth(15)
for i in enumerate(axes):
    sns.distplot(review[review.Rating==i[0]+1].iloc[:,2],ax=i[1])

# %%
plt.pie(review.Rating.value_counts())
plt.legend(review.Rating.value_counts().index)

# %%
review[review.Rating==1].describe()
# Out:
#        Rating   review_len  word_length
# count  1421.0  1421.000000  1421.000000
# mean      1.0   769.940183   114.365236
# std       0.0   687.590339    99.834855
# min       1.0    77.000000    14.000000
# 25%       1.0   351.000000    53.000000
# 50%       1.0   564.000000    84.000000
# 75%       1.0   943.000000   139.000000
# max       1.0  6511.000000   956.000000

# %%
review[review.Rating==2].describe()
# Out:
#        Rating   review_len  word_length
# count  1793.0  1793.000000  1793.000000
# mean      2.0   867.645287   128.598438
# std       0.0   746.485926   108.258642
# min       2.0    74.000000    12.000000
# 25%       2.0   433.000000    65.000000
# 50%       2.0   654.000000    97.000000
# 75%       2.0  1028.000000   150.000000
# max       2.0  7988.000000  1111.000000

# %%
review[review.Rating==3].describe()
# Out:
#        Rating    review_len  word_length
# count  2184.0   2184.000000  2184.000000
# mean      3.0    785.000000   116.705586
# std       0.0    744.590055   109.023017
# min       3.0     47.000000    11.000000
# 25%       3.0    370.750000    56.000000
# 50%       3.0    588.000000    88.000000
# 75%       3.0    932.500000   136.000000
# max       3.0  13501.000000  1933.000000

# %%
review[review.Rating==4].describe()
# Out:
#        Rating    review_len  word_length
# count  6039.0   6039.000000  6039.000000
# mean      4.0    745.688690   109.771154
# std       0.0    730.521733   107.132896
# min       4.0     61.000000    11.000000
# 25%       4.0    340.500000    51.000000
# 50%       4.0    539.000000    80.000000
# 75%       4.0    885.000000   130.000000
# max       4.0  10062.000000  1460.000000

# %%
review[review.Rating==5].describe()
# Out:
#        Rating    review_len  word_length
# count  9054.0   9054.000000  9054.000000
# mean      5.0    661.981445    95.962889
# std       0.0    627.544288    90.977128
# min       5.0     44.000000     9.000000
# 25%       5.0    318.000000    46.000000
# 50%       5.0    496.000000    71.000000
# 75%       5.0    784.000000   113.000000
# max       5.0  12762.000000  1757.000000

# %%
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length
# 0               89
# ...

# %%
review['sentiment']=0
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment
# ...

# %%
review.loc[(review.Rating==4) | (review.Rating==5),'sentiment']=1

# %%
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment
# ...

# %%
plt.pie(review.sentiment.value_counts())
plt.legend(['positive','negative'])

# %%
fig, axes = plt.subplots(2,1,sharex='col', sharey='col')
fig.set_figheight(15)
fig.set_figwidth(15)
for i in enumerate(axes):
        sns.distplot(review[review.sentiment==i[0]].iloc[:,2],ax=i[1])

# %%
plt.figure(figsize=(12,8))
colors=["red","blue"]
for i in range(2):
    review[review.sentiment==i].review_len.plot(bins=30,kind="hist",color=colors[i-1],label=i,alpha=0.6)
plt.legend() 
plt.xlabel("Review Length")
# Out:
# Text(0.5, 0, 'Review Length')

# %%
rating_length_sent=review.groupby(["sentiment"]).mean()
plt.bar(['negative','positive'],rating_length_sent.review_len)
# Out:
# <BarContainer object of 2 artists>

# %%
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import string
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def process_text(sample_string):
    STOPWORDS=stopwords.words("english")+['nt']+['hotel']
    no_punc=[i for i in sample_string if i not in string.punctuation]
    no_punc=''.join(no_punc)
    no_punc= word_tokenize(no_punc)
    no_stop=[word for word in no_punc if word not in STOPWORDS]
    lem=[]
    for i in no_stop:
        lem.append(lemmatizer.lemmatize(i))
    return' '.join(lem)

# %%
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment
# ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shanal\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\shanal\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
review["clean_text"]=review.Review.apply(process_text)
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment  \
# ...

# %%
from collections import Counter
words_counter=[]
words=[]
for i in range(5):
    words.append(review[review.Rating==i+1].clean_text.apply(lambda x: [word.lower() for word in x.split()]))
    words_counter.append(Counter())
    
    for word in words[i]:
        words_counter[i].update(word)

# %%
print(words_counter[0].most_common(50))
# Out:
# [('room', 4166), ('stay', 1221), ('day', 1173), ('night', 1127), ('staff', 966), ('time', 909), ('service', 873), ('place', 728), ('like', 715), ('told', 707), ('resort', 695), ('bed', 642), ('desk', 639), ('got', 629), ('food', 616), ('good', 611), ('stayed', 611), ('people', 540), ('went', 499), ('2', 476), ('beach', 473), ('booked', 450), ('bad', 437), ('water', 435), ('hour', 426), ('bathroom', 426), ('said', 423), ('restaurant', 417), ('experience', 411), ('door', 410), ('asked', 394), ('thing', 390), ('minute', 387), ('3', 385), ('pool', 375), ('reservation', 373), ('better', 369), ('nice', 365), ('problem', 363), ('small', 363), ('breakfast', 363), ('check', 362), ('guest', 361), ('manager', 360), ('really', 360), ('say', 357), ('called', 354), ('floor', 352), ('star', 345), ('worst', 343)]

# %%
for i in range(5):
    print("50 most common words for rating {}".format(i+1))
    print(words_counter[i].most_common(50))
# Out:
# 50 most common words for rating 1
# [('room', 4166), ('stay', 1221), ('day', 1173), ('night', 1127), ('staff', 966), ('time', 909), ('service', 873), ('place', 728), ('like', 715), ('told', 707), ('resort', 695), ('bed', 642), ('desk', 639), ('got', 629), ('food', 616), ('good', 611), ('stayed', 611), ('people', 540), ('went', 499), ('2', 476), ('beach', 473), ('booked', 450), ('bad', 437), ('water', 435), ('hour', 426), ('bathroom', 426), ('said', 423), ('restaurant', 417), ('experience', 411), ('door', 410), ('asked', 394), ('thing', 390), ('minute', 387), ('3', 385), ('pool', 375), ('reservation', 373), ('better', 369), ('nice', 365), ('problem', 363), ('small', 363), ('breakfast', 363), ('check', 362), ('guest', 361), ('manager', 360), ('really', 360), ('say', 357), ('called', 354), ('floor', 352), ('star', 345), ('worst', 343)]
# 50 most common words for rating 2
# ...

# %%
words[0]
# Out:
# 15       [horrible, customer, service, stay, february, ...
# 32       [noise, airconditionera, standard, arranged, s...
# 40       [bad, choice, booked, hot, wire, called, immed...
# 65       [hated, inn, terrible, roomservice, horrible, ...
# 69       [ace, grunge, life, mold, mildew, tiny, bed, m...
#                                ...
# 20421    [worst, sleep, hip, tooooo, hip, nite, club, b...
# 20460    [june, 08, stay, stayed, june, 666808, read, r...
# 20465    [stay, brought, group, february, worst, experi...
# 20467    [returning, la, concha, nightmare, surprising,...
# 20489    [theft, ruined, vacation, opened, sept, 17, 20...
# Name: clean_text, Length: 1421, dtype: object

# %%
from spacy.cli import download
download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
review['noun_pharces']=review.clean_text.apply(nlp)

# %%
a=[]
for i in review.noun_pharces:
    a.append([chunk.text for chunk in i.noun_chunks])

# %%
review['noun_pharces']=a

# %%
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment  \
# ...

# %%
from collections import Counter
nouns_counter=[]
noun_sentences=[]
for i in range(5):
    noun_sentences.append(review[review.Rating==i+1].noun_pharces.apply(lambda x: [word.lower() for word in x]))
    nouns_counter.append(Counter())
    
    for word in noun_sentences[i]:
        nouns_counter[i].update(word)

# %%
for i in range(5):
    print("50 most commom words for rating {}".format(i+1))
    print(nouns_counter[i].most_common(50))
# Out:
# 50 most commom words for rating 1
# [('people', 174), ('room', 172), ('nothing', 108), ('place', 102), ('desk', 68), ('money', 61), ('staff', 58), ('resort', 56), ('time', 54), ('food', 53), ('reservation', 47), ('husband', 40), ('door', 39), ('review', 39), ('bed', 38), ('problem', 36), ('help', 35), ('hotel', 26), ('dinner', 26), ('pool', 25), ('day', 25), ('fact', 24), ('check', 24), ('credit card', 22), ('none', 22), ('thing', 22), ('sleep', 20), ('donçé', 20), ('airport', 19), ('water', 19), ('wife', 18), ('god', 18), ('i', 18), ('guest', 17), ('english', 17), ('work', 17), ('book', 17), ('trip', 17), ('that', 17), ('punta cana', 17), ('bag', 15), ('manager', 15), ('reception', 14), ('luggage', 14), ('inn', 14), ('night', 14), ('refund', 13), ('shower', 13), ('restaurant', 13), ('mistake', 13)]
# 50 most commom words for rating 2
# ...

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
review.clean_text
# Out:
# 0        nice expensive parking got good deal stay anni...
# 1        ok nothing special charge diamond member hilto...
# 2        nice room 4 experience monaco seattle good 4 l...
# 3        unique great stay wonderful time monaco locati...
# 4        great stay great stay went seahawk game awesom...
#                                ...
# 20486    best kept secret 3rd time staying charm 5star ...
# 20487    great location price view great quick place si...
# 20488    ok look nice modern outside desk staff particu...
# 20489    theft ruined vacation opened sept 17 2007 gues...
# 20490    people talking ca believe excellent rating yes...
# Name: clean_text, Length: 20491, dtype: object

# %%
text_positive=' '.join(review[review.sentiment==1].clean_text)
text_negative=' '.join(review[review.sentiment==0].clean_text)

# %%
wordcloud_positive = WordCloud(stopwords = STOPWORDS,
                              collocations=True).generate(text_positive)

# %%
plt.imshow(wordcloud_positive, interpolation='bilInear')
plt.axis('off')
plt.title('positive')
plt.show()

# %%
wordcloud_negative = WordCloud(stopwords = STOPWORDS,
                              collocations=True).generate(text_negative)

# %%
plt.imshow(wordcloud_negative, interpolation='bilInear')
plt.axis('off')
plt.title('negative')
plt.show()

# %%
review
# Out:
#                                                   Review  Rating  review_len  \
# 0      nice hotel expensive parking got good deal sta...     4.0         593
# 1      ok nothing special charge diamond member hilto...     2.0        1689
# 2      nice rooms not 4* experience hotel monaco seat...     3.0        1427
# 3      unique, great stay, wonderful time hotel monac...     5.0         600
# 4      great stay great stay, went seahawk game aweso...     5.0        1281
# ...                                                  ...     ...         ...
# 20486  best kept secret 3rd time staying charm, not 5...     5.0         733
# 20487  great location price view hotel great quick pl...     4.0         306
# 20488  ok just looks nice modern outside, desk staff ...     2.0         443
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0        5557
# 20490  people talking, ca n't believe excellent ratin...     2.0         620
#
#        word_length  sentiment  \
# ...

# %%
x = review.clean_text
y = review.sentiment
print(x.shape)
print(y.shape)
# Out:
# (20491,)
# (20491,)

# %%
from sklearn.model_selection  import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15368,)
# (5123,)
# (15368,)
# (5123,)

# %%
train_pre_resampling=pd.concat([x_train,y_train],axis=1)

# %%
train_pre_resampling.sentiment.value_counts()
# Out:
# 1    11290
# 0     4078
# Name: sentiment, dtype: int64

# %%
from sklearn import utils
resampled_negative=utils.resample(train_pre_resampling[train_pre_resampling.sentiment==0],replace=True,n_samples=11290)

# %%
train=pd.concat([resampled_negative,train_pre_resampling[train_pre_resampling.sentiment==1]])

# %%
train
# Out:
#                                               clean_text  sentiment
# 1930   room small great view parking ramp block away ...          0
# 14356  stylish ice cold staff stayed conrad miami nig...          0
# 83     holiday inn 1st time seattle delayed anniversa...          0
# 10248  run away stay safer staff okay long tipped rea...          0
# 15533  roll royce hotel returned peninsula 2008 immed...          0
# ...                                                  ...        ...
# 19279  loved hipster belmont live city decided celebr...          1
# 17289  felt special november 1st arrived fro 3 day vi...          1
# 5192   amistad 10 point wow amistad stay amsterdam pl...          1
# 12172  absolutely perfect mu husband stayed number ti...          1
# 235    nice beware 26 parkingvalet fee great location...          1
#
# [22580 rows x 2 columns]

# %%
x_train=train.clean_text
y_train=train.sentiment

# %%
from sklearn.feature_extraction.text import CountVectorizer

# instantiate the vectozier
vect = CountVectorizer()
vect.fit(x_train)
# Out:
# CountVectorizer()

# %% [markdown]
# in a jupyter environment.please rerun this cell to show the HTML representation or trust the notebook.
# on Github, the HTML represnetaion is unable to render,please try loading this page with nbviewer.org.

# %%
x_train_dtm = vect.transform(x_train)

# %%
x_train_dtm
# Out:
# <22580x62971 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1815491 stored elements in Compressed Sparse Row format>

# %%
x_test_dtm = vect.transform(x_test)

# %%
x_test_dtm
# Out:
# <5123x62971 sparse matrix of type '<class 'numpy.int64'>'
# 	with 386710 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(x_train_dtm)
tfidf_transformer.transform(x_train_dtm)
# Out:
# <22580x62971 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1815491 stored elements in Compressed Sparse Row format>

# %%
x_train_dtm
# Out:
# <22580x62971 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1815491 stored elements in Compressed Sparse Row format>
